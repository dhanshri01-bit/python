# %%
# Mini Project of Result management system

fail_sub = ''
num_fail = 0

#taking input from the user  for five subjects (totalmarks and obtained marks)
# also checking student is having supplementary in any subject

S1 = 'English'
mm_E = int(input('Enter maximum marks of english'))
if( mm_E > 0 ) and (mm_E <= 100):
    ob_m_E = int(input('Enter obtained marks'))
    
    if(ob_m_E <= mm_E) and (ob_m_E > 0):
        passing = 40/100 * mm_E 
        
        if(ob_m_E < passing):
            fail_sub = S1
            num_fail += 1
    else:
        print('enter obtained marks in range of maximum marks')
else:
    print('please enter vaild marks')

S2 = 'Hindi'
mm_H = int(input('Enter maximum marks of Hindi'))
if( mm_H > 0 ) and (mm_H <= 100):
    ob_m_H = int(input('Enter obtained marks'))
    
    if(ob_m_H <= mm_H) and (ob_m_H > 0):
        passing = 40/100 * mm_H 

        if(ob_m_H < passing):
            fail_sub = fail_sub + ' ' + S2
            num_fail += 1
    else:
         print('enter obtained marks in range of maximum marks')
        
else:
    print('please enter vaild marks')

    
S3 = 'Physics'
mm_P = int(input('Enter maximum marks of physics'))
if( mm_P > 0 ) and (mm_P <= 100):
    ob_m_P = int(input('Enter obtained marks'))
    
    if(ob_m_P <= mm_P) and (ob_m_P > 0):
        passing = 40/100 * mm_P 

        if(ob_m_P < passing):
            fail_sub = fail_sub + ' ' + S3
            num_fail += 1 
    else:
        print('enter obtainted marks in range of maximum marks')
else:
    print('please enter vaild marks')


S4 = 'Chemistry'
mm_C = int(input('Enter maximum marks of chemistry'))
if( mm_C > 0 ) and (mm_C <= 100):
    ob_m_C = int(input('Enter obtained marks'))
    
    if(ob_m_C <= mm_C) and (ob_m_C > 0):
        passing = 40/100 * mm_C 

        if(ob_m_C < passing):
            fail_sub = fail_sub + ' ' + S4
            num_fail += 1
    else:
         print('enter obtained marks in range of maximum marks')
        
else:
    print('please enter vaild marks')
    

S5 = 'Maths'
mm_M = int(input('Enter maximum marks of maths'))
if( mm_M > 0) and (mm_M <= 100):
    ob_m_M = int(input('Enter obtained marks'))
    
    if(ob_m_M <= mm_M) and (ob_m_M > 0):
        passing = 40/100 * mm_M 

        if(ob_m_M < passing):
            fail_sub = fail_sub + ' ' + S5
            num_fail += 1
    else:
         print('enter obtained marks in range of maximum marks')
        
else:
    print('please enter vaild marks')

#check if student has supplementary

if(num_fail <= 2) and (num_fail != 0):

    print('Supplementary in Subjects:')
    print(fail_sub)

#check if student is fail in more than 3 subjects

elif(num_fail > 2):

    print('Student is fail')
    
# Display the result if student is pass in all subjects

else:
    
        Total_marks = mm_E + mm_H + mm_P + mm_C + mm_M
        Obtained_marks = ob_m_E + ob_m_H + ob_m_P + ob_m_C + ob_m_M
        Percentage = Obtained_marks /Total_marks * (100)

        if Percentage >= 90:
            grade = "A+"
        elif Percentage >= 80:
             grade = "A"
        elif Percentage >= 70:
             grade = "B"
        elif Percentage >= 60:
             grade = "C"
        elif Percentage >= 50:
             grade = "D"
        else:
             grade = "E"

        print('Student Result: PASS')
        print('TotalMarks: ',Total_marks)
        print('Obtained marks: ', Obtained_marks)
        print('Percentage: ',Percentage)
        print('Grade: ', grade)
    
student_name = 'Dhanshri Wagh'
std = 'XII'
s1 = 'English'
s2 = 'Hindi'
s3 =  'Physics'
s4 ='Chemistry'
s5 = 'Mathematics'

print(f'Name of student : {student_name.upper():<20} Class :{std}')


print('-'*50)
heads = f"{'Subject':<12}|{'MM':^3}|{'OM':>3}|"
line1 =  f"{s1:<12}|{mm_E:^3}|{ob_m_E:>3}|"
line2 =  f"{s2:<12}|{mm_H:^3}|{ob_m_H:>3}|"
line3=  f"{s3:<12}|{mm_P:^3}|{ob_m_P:>3}|"
line4=  f"{s4:<12}|{mm_C:^3}|{ob_m_C:>3}|"
line5=  f"{s5:<12}|{mm_M:^3}|{ob_m_M:>3}|"

print(heads)
print("-" * 21)
print(line1)
print("-" * 21)
print(line2)
print("-" * 21)
print(line3)
print("-" * 21)
print(line4)
print("-" * 21)
print(line5)
print("-" * 21)
print(f'Total :{Obtained_marks:>13}|')
print('-'*50)
# Out:
# Enter maximum marks of english 100
# Enter obtained marks 56
# Enter maximum marks of Hindi 24
# Enter obtained marks 1
# Enter maximum marks of physics 70
# Enter obtained marks 45
# Enter maximum marks of chemistry 70
# Enter obtained marks 45
# Enter maximum marks of maths 100
# Enter obtained marks 80
# Supplementary in Subjects:
#  Hindi
# Name of student : DHANSHRI WAGH        Class :XII
# --------------------------------------------------
# Subject     |MM | OM|
# ---------------------
# English     |100| 56|
# ---------------------
# Hindi       |24 |  1|
# ---------------------
# Physics     |70 | 45|
# ---------------------
# Chemistry   |70 | 45|
# ---------------------
# Mathematics |100| 80|
# ---------------------
# Total :          267|
# --------------------------------------------------
